# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
def check_input(square):
    # checking for data being an integer value
    for i in range(len(square)):
        for j in range(len(square)):
          if isinstance(square[i][j], int):
            continue
          else:
            return False

    # checking in rows
    for i in range(len(square)):
        val = square[i][0]
        for j in range(len(square[0])):
            if val == square[i][j] and j != 0:
                return False

    # checking for columns
    for i in range(len(square)):
        val = square[0][i]
        for j in range(len(square[0])):
            if val == square[j][i] and j != 0:
                return False

    return True

# %%
# run this block to test code after defining the procedure

test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false
# Out:
# True
# False
# False

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
# !wget https://drive.google.com/file/d/15Mi7J35JQ3kqZTSb5EVKbK4-6G5wEpwJ/view?usp=sharing
# Out:
# --2022-09-18 13:33:42--  https://drive.google.com/file/d/15Mi7J35JQ3kqZTSb5EVKbK4-6G5wEpwJ/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 142.250.141.100, 142.250.141.138, 142.250.141.101, ...
# Connecting to drive.google.com (drive.google.com)|142.250.141.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view?usp=sharing.1’
#
# view?usp=sharing.1      [ <=>                ]  66.25K  --.-KB/s    in 0.009s
#
# 2022-09-18 13:33:43 (7.08 MB/s) - ‘view?usp=sharing.1’ saved [67842]

# %%
import pandas as pd
data = pd.read_csv("StudentMarkSheet.csv")
data
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [200 rows x 4 columns]

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
len(data.index)
# Out:
# 200

# %%
data.isnull().sum().sum()
# Out:
# 4

# %%
len(data.dropna())
# Out:
# 196

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
data = pd.read_csv("StudentMarkSheet.csv")
data.set_index("Student name",inplace=True)
marks=data.loc["James Walker"]
marks
# Out:
#                 Exam name   Exam date  Marks
# Student name
# James Walker      Biology  05/06/2016   31.0
# James Walker    Chemistry  15/06/2016   61.0
# James Walker  Mathematics  29/07/2016   23.0
# James Walker      Physics  10/06/2016  100.0
# James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("StudentMarkSheet.csv")
data.set_index("Exam name",inplace=True)
biology=data.loc["Biology"].mean()
chemistry=data.loc["Chemistry"].mean()
math=data.loc["Mathematics"].mean()
phylo=data.loc["Philosophy"].mean()
phy=data.loc["Physics"].mean()
socio=data.loc["Sociology"].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   import sys
# ...

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
bar_data=pd.DataFrame({'Biology':biology,'Chemistry':chemistry,'Mathematics':math,'Philosophy':phylo,'Physics':phy,'Sociology':socio})
bar_data.head(6).plot(kind='bar',figsize=(15,7))

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
# !wget https://drive.google.com/file/d/1d_3c7iD2wF59yXPTB5pWNFSjdYi5mSGG/view?usp=sharing
# Out:
# --2022-09-18 13:33:10--  https://drive.google.com/file/d/1d_3c7iD2wF59yXPTB5pWNFSjdYi5mSGG/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 74.125.137.113, 74.125.137.101, 74.125.137.100, ...
# Connecting to drive.google.com (drive.google.com)|74.125.137.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view?usp=sharing’
#
# view?usp=sharing        [ <=>                ]  66.21K  --.-KB/s    in 0.009s
#
# 2022-09-18 13:33:11 (7.15 MB/s) - ‘view?usp=sharing’ saved [67797]

# %%
newdata=pd.read_csv("CatData.csv")
newdata.dropna()
newdata
# Out:
#      Tail Length (cm)  Mass (kg)
# 0                18.1      3.750
# 1                18.6      3.800
# 2                19.5      3.250
# 3                19.3      3.450
# 4                19.0      3.650
# ..                ...        ...
# 337              20.7      4.000
# 338              20.2      3.400
# 339              19.3      3.775
# 340              21.0      4.100
# 341              19.8      3.775
#
# [342 rows x 2 columns]

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
# dependant variable: Length of tail  
# independant variable: Mass in kg

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
from sklearn import linear_model

num = int(len(newdata)*0.8)
train = newdata[:num] # 80% traning
test = newdata[num:]  #20% testing

print("data", len(newdata))
print("train", len(train))
print("test", len(test))

model = linear_model.LinearRegression()
train_x_axis = np.array(train[["Mass (kg)"]])
train_y_axis = np.array(train[["Tail Length (cm)"]])

model.fit(train_x_axis, train_y_axis)

slope = model.coef_
intercept = model.intercept_
# Out:
# data 342
# train 273
# test 69

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
print("slope", slope[0])
print("intercept", intercept)
# Out:
# slope [1.25869865]
# intercept [14.46678295]

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
plt.scatter(newdata["Mass (kg)"],newdata["Tail Length (cm)"])
plt.plot(train_x_axis, slope[0]*train_x_axis + intercept, color="black")
plt.xlabel("Mass (kg)")
plt.ylabel("Tail Length (cm)")
plt.show()
